# %% [markdown]
# # Project: Real-Time Mask Detector (YOLOv5)

# %% [markdown]
# In this notebook, we will be building a program to detect whether a person is wearing a mask or not, i.e., a mask detector. The situation is as follows: we have a camera that records video of a very busy area (for example, the entrance of a shopping center, a school, etc.) and we want to detect in real time if someone is not wearing a mask in order to warn him or prevent him from passing. The "real-time" condition suggests using models that can perform this task in one-stage, such as YOLO, SSD or RetinaNet. However, two-stage models can still perform well, since the number of classes is not too high. In this project we will use YOLOv5 as our detector model.
#
# This Colab Notebook is part of the post [Real-time object detection - YOLOv5
# ](https://mathchine-learning.blogspot.com/2020/10/real-time-object-detection-yolov5.html) from my blog [Mathchine Learning](https://mathchine-learning.blogspot.com/). I recommend reading the post before going any further in this notebook.
#
# In case you are not interested in the model and the training process, you can directly skip to the Testing section to see our YOLOv5s Mask Detector in action. Although, you will miss a lot!

# %% [markdown]
# ## Table of contents
# - [1.  Data in YOLOv5](#1)
#     - [1.1  Understanding the data](#1.1)
#     - [1.2  Loading the data](#1.2)
#     - [1.3  MetaData](#1.3)
#         - [1.3.1  Creating the MetaData files](#1.3.1)
#         - [1.3.2  Processing the MetaData](#1.3.2)
#         - [1.3.3  Conclusions about the MetaData](#1.3.3)
#     - [1.4  Preprocessing](#1.4)
#         - [1.4.1  Convert labels to YOLOs format](#1.4.1)
#         - [1.4.2  Copy the images](#1.4.2)
#     - [1.5  Data visualization](#1.5)
#     - [1.6  Helper functions](#1.6)
# - [2.  The model](#2)
#     - [2.1  Cloning and importing libraries](#2.1)
#     - [2.2  Configuration files](#2.2)
# - [3.  Training](#3)
# - [4.  Testing](#4)
#     - [4.1  Fast setup (optional)](#4.1)
#     - [4.2  Image detection](#4.2)
#     - [4.3  Video detection](#4.3)
#     - [4.4  Conclusion](#4.4)

# %% [markdown]
# <a name="1"></a>
# # 1. Data in YOLOv5

# %% [markdown]
# <a name="1.1"></a>
# ## 1.1 Understanding the data

# %% [markdown]
# First, we will load the dataset we will use to train our model. The dataset is called [Face Mask Detection](https://www.kaggle.com/andrewmvd/face-mask-detection) and it was download to Kaggle by andrewmvd.
#
# The dataset contains 853 images labeled using the Pascal VOC format. In this format, there is one XML file for each image using the same name as the corresponding image file. The XML file contains the description of the bounding boxes, together with the class associated to each bounding box. Hence, in our case, we have also 853 XML files containing the bounding boxes that indicate where the head of each individual is located on its corresponding image and a class assigned according to whether the individual is using a mask, is not using it or is using it incorrectly.
#
# Let's see an example of a pair (image, label). Here is the image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# And here is its corresponding XML file.

# %% [markdown]
# ```
# <annotation>
#     <folder>images</folder>
#     <filename>maksssksksss0.png</filename>
#     <size>
#         <width>512</width>
#         <height>366</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>without_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>79</xmin>
#             <ymin>105</ymin>
#             <xmax>109</xmax>
#             <ymax>142</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>with_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>185</xmin>
#             <ymin>100</ymin>
#             <xmax>226</xmax>
#             <ymax>144</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>without_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>325</xmin>
#             <ymin>90</ymin>
#             <xmax>360</xmax>
#             <ymax>141</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```

# %% [markdown]
# As you can see, there is not only information about the objects. It also contains some general information like the size of the image.

# %% [markdown]
# Unfortunately, neither YOLO nor any other known object detection model uses this format. Therefore, once we have downloaded the database, we will have to preprocess the labels.

# %% [markdown]
# <a name="1.2"></a>
# ## 1.2 Loading the data

# %% [markdown]
# In this section, we are downloading the data from Kaggle. To do that, follow these steps:
# *   Log in to your Kaggle account.
# *   Go to "My account" and create a new API token.
# *   You will get a json file, open it and copy the username and the key and past them in the code below.

# %%
# Configuration environment
from IPython.display import clear_output  
import os

# Copy the username and key from the json file.
os.environ['KAGGLE_USERNAME'] = "amirfo" # username from the json file
os.environ['KAGGLE_KEY'] = "51c904817b182db1fe201eec6af75541" # key from the json file

# Download the Face Mask Detection dataset from Kaggle
# !kaggle datasets download -d andrewmvd/face-mask-detection

clear_output()
print('Face Mask Detection dataset downloaded.')
# Out:
# Face Mask Detection dataset downloaded.

# %% [markdown]
# We will also create the directory structure for the project:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pathMaskDetector = os.path.join('/content', 'Mask_Detector')
os.mkdir(pathMaskDetector)

pathMaskdataset = os.path.join(pathMaskDetector, 'Mask_dataset')
os.mkdir(pathMaskdataset)

pathPreprocesseddataset = os.path.join(pathMaskDetector, 'Preprocessed_dataset')
os.mkdir(pathPreprocesseddataset)

pathDarknet = os.path.join(pathMaskDetector, 'Darknet')
os.mkdir(pathDarknet)

pathConfigurationfiles = os.path.join(pathMaskDetector, 'Configuration_files')
os.mkdir(pathConfigurationfiles)

pathWeights = os.path.join(pathMaskDetector, 'Weights')
os.mkdir(pathWeights)

pathMetaData = os.path.join(pathMaskDetector, 'MetaData')
os.mkdir(pathMetaData)

# %% [markdown]
# Finally, we will unzip the data in its corresponding directory.

# %%
# Unzip the file
# !unzip face-mask-detection.zip -d Mask_Detector/Mask_dataset

clear_output()
print('Face Mask Detection dataset uncompressed.')
# Out:
# Face Mask Detection dataset uncompressed.

# %% [markdown]
# <a name="1.3"></a>
# ## 1.3 MetaData

# %% [markdown]
# Before we start with the database preprocessing, let's see what we have here. In this section, we will see general but relevant information about the dataset, such as how many bounding boxes we have of each class or where in the image these boxes are usually located. To do that, we will need the following libraries.

# %%
# Importing libraries
import numpy as np
# !pip install xmltodict
import xmltodict
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the pathes
pathimages = os.path.join(pathMaskdataset, 'images')
pathannotations = os.path.join(pathMaskdataset, 'annotations')
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %% [markdown]
# <a name="1.3.1"></a>
# ### 1.3.1 Creating the MetaData files

# %% [markdown]
# First, we create two lists of file names, one for the images and one for the XMLs files.

# %%
# File names
imageFilesNames = []  # List of imagefile names
labelFilesNames = []  # List of xmlfile names

for dirpath, dirnames, filenames in os.walk(pathMaskdataset):
    for filename in filenames:
        if filename[-3:] == "xml":
            labelFilesNames.append(filename)
        elif filename[-3:] == "png":
            imageFilesNames.append(filename)

print(imageFilesNames)
print(labelFilesNames)
# Out:
# ['maksssksksss149.png', 'maksssksksss346.png', 'maksssksksss728.png', 'maksssksksss625.png', 'maksssksksss84.png', 'maksssksksss130.png', 'maksssksksss482.png', 'maksssksksss547.png', 'maksssksksss797.png', 'maksssksksss755.png', 'maksssksksss832.png', 'maksssksksss653.png', 'maksssksksss98.png', 'maksssksksss677.png', 'maksssksksss303.png', 'maksssksksss263.png', 'maksssksksss299.png', 'maksssksksss1.png', 'maksssksksss765.png', 'maksssksksss348.png', 'maksssksksss565.png', 'maksssksksss557.png', 'maksssksksss341.png', 'maksssksksss839.png', 'maksssksksss650.png', 'maksssksksss736.png', 'maksssksksss748.png', 'maksssksksss421.png', 'maksssksksss815.png', 'maksssksksss850.png', 'maksssksksss87.png', 'maksssksksss525.png', 'maksssksksss554.png', 'maksssksksss743.png', 'maksssksksss85.png', 'maksssksksss121.png', 'maksssksksss441.png', 'maksssksksss335.png', 'maksssksksss32.png', 'maksssksksss591.png', 'maksssksksss66.png', 'maksssksksss701.png', 'maksssksksss243.png', 'maksssksksss187.png', 'maksssksksss145.png', 'maksssksksss531.png', 'maksssksksss126.png', 'maksssksksss505.png', 'maksssksksss738.png', 'maksssksksss118.png', 'maksssksksss619.png', 'maksssksksss91.png', 'maksssksksss34.png', 'maksssksksss280.png', 'maksssksksss339.png', 'maksssksksss377.png', 'maksssksksss88.png', 'maksssksksss693.png', 'maksssksksss753.png', 'maksssksksss811.png', 'maksssksksss533.png', 'maksssksksss569.png', 'maksssksksss206.png', 'maksssksksss791.png', 'maksssksksss331.png', 'maksssksksss537.png', 'maksssksksss354.png', 'maksssksksss312.png', 'maksssksksss192.png', 'maksssksksss334.png', 'maksssksksss768.png', 'maksssksksss806.png', 'maksssksksss290.png', 'maksssksksss716.png', 'maksssksksss359.png', 'maksssksksss360.png', 'maksssksksss621.png', 'maksssksksss785.png', 'maksssksksss544.png', 'maksssksksss305.png', 'maksssksksss705.png', 'maksssksksss287.png', 'maksssksksss581.png', 'maksssksksss477.png', 'maksssksksss813.png', 'maksssksksss754.png', 'maksssksksss347.png', 'maksssksksss132.png', 'maksssksksss322.png', 'maksssksksss435.png', 'maksssksksss442.png', 'maksssksksss344.png', 'maksssksksss107.png', 'maksssksksss824.png', 'maksssksksss530.png', 'maksssksksss808.png', 'maksssksksss282.png', 'maksssksksss416.png', 'maksssksksss784.png', 'maksssksksss387.png', 'maksssksksss65.png', 'maksssksksss849.png', 'maksssksksss816.png', 'maksssksksss386.png', 'maksssksksss396.png', 'maksssksksss586.png', 'maksssksksss328.png', 'maksssksksss19.png', 'maksssksksss437.png', 'maksssksksss203.png', 'maksssksksss601.png', 'maksssksksss111.png', 'maksssksksss719.png', 'maksssksksss843.png', 'maksssksksss318.png', 'maksssksksss497.png', 'maksssksksss349.png', 'maksssksksss406.png', 'maksssksksss673.png', 'maksssksksss558.png', 'maksssksksss0.png', 'maksssksksss258.png', 'maksssksksss74.png', 'maksssksksss193.png', 'maksssksksss44.png', 'maksssksksss279.png', 'maksssksksss355.png', 'maksssksksss851.png', 'maksssksksss302.png', 'maksssksksss247.png', 'maksssksksss759.png', 'maksssksksss120.png', 'maksssksksss702.png', 'maksssksksss68.png', 'maksssksksss37.png', 'maksssksksss27.png', 'maksssksksss771.png', 'maksssksksss153.png', 'maksssksksss735.png', 'maksssksksss840.png', 'maksssksksss369.png', 'maksssksksss317.png', 'maksssksksss432.png', 'maksssksksss714.png', 'maksssksksss504.png', 'maksssksksss539.png', 'maksssksksss624.png', 'maksssksksss224.png', 'maksssksksss494.png', 'maksssksksss357.png', 'maksssksksss260.png', 'maksssksksss307.png', 'maksssksksss208.png', 'maksssksksss25.png', 'maksssksksss229.png', 'maksssksksss845.png', 'maksssksksss127.png', 'maksssksksss542.png', 'maksssksksss340.png', 'maksssksksss105.png', 'maksssksksss57.png', 'maksssksksss211.png', 'maksssksksss422.png', 'maksssksksss238.png', 'maksssksksss734.png', 'maksssksksss555.png', 'maksssksksss273.png', 'maksssksksss210.png', 'maksssksksss31.png', 'maksssksksss424.png', 'maksssksksss54.png', 'maksssksksss367.png', 'maksssksksss550.png', 'maksssksksss778.png', 'maksssksksss300.png' ...
# ['maksssksksss348.xml', 'maksssksksss19.xml', 'maksssksksss165.xml', 'maksssksksss764.xml', 'maksssksksss493.xml', 'maksssksksss832.xml', 'maksssksksss555.xml', 'maksssksksss194.xml', 'maksssksksss197.xml', 'maksssksksss222.xml', 'maksssksksss461.xml', 'maksssksksss240.xml', 'maksssksksss833.xml', 'maksssksksss475.xml', 'maksssksksss331.xml', 'maksssksksss443.xml', 'maksssksksss530.xml', 'maksssksksss372.xml', 'maksssksksss70.xml', 'maksssksksss815.xml', 'maksssksksss590.xml', 'maksssksksss685.xml', 'maksssksksss319.xml', 'maksssksksss532.xml', 'maksssksksss231.xml', 'maksssksksss588.xml', 'maksssksksss804.xml', 'maksssksksss218.xml', 'maksssksksss656.xml', 'maksssksksss183.xml', 'maksssksksss151.xml', 'maksssksksss681.xml', 'maksssksksss106.xml', 'maksssksksss306.xml', 'maksssksksss686.xml', 'maksssksksss749.xml', 'maksssksksss742.xml', 'maksssksksss850.xml', 'maksssksksss347.xml', 'maksssksksss177.xml', 'maksssksksss300.xml', 'maksssksksss52.xml', 'maksssksksss176.xml', 'maksssksksss315.xml', 'maksssksksss489.xml', 'maksssksksss166.xml', 'maksssksksss230.xml', 'maksssksksss467.xml', 'maksssksksss317.xml', 'maksssksksss174.xml', 'maksssksksss509.xml', 'maksssksksss173.xml', 'maksssksksss288.xml', 'maksssksksss89.xml', 'maksssksksss477.xml', 'maksssksksss303.xml', 'maksssksksss788.xml', 'maksssksksss68.xml', 'maksssksksss415.xml', 'maksssksksss487.xml', 'maksssksksss242.xml', 'maksssksksss354.xml', 'maksssksksss307.xml', 'maksssksksss244.xml', 'maksssksksss196.xml', 'maksssksksss496.xml', 'maksssksksss86.xml', 'maksssksksss356.xml', 'maksssksksss480.xml', 'maksssksksss435.xml', 'maksssksksss150.xml', 'maksssksksss249.xml', 'maksssksksss369.xml', 'maksssksksss519.xml', 'maksssksksss79.xml', 'maksssksksss610.xml', 'maksssksksss585.xml', 'maksssksksss188.xml', 'maksssksksss211.xml', 'maksssksksss583.xml', 'maksssksksss147.xml', 'maksssksksss279.xml', 'maksssksksss700.xml', 'maksssksksss843.xml', 'maksssksksss463.xml', 'maksssksksss534.xml', 'maksssksksss670.xml', 'maksssksksss827.xml', 'maksssksksss525.xml', 'maksssksksss55.xml', 'maksssksksss193.xml', 'maksssksksss811.xml', 'maksssksksss238.xml', 'maksssksksss665.xml', 'maksssksksss437.xml', 'maksssksksss14.xml', 'maksssksksss46.xml', 'maksssksksss200.xml', 'maksssksksss6.xml', 'maksssksksss360.xml', 'maksssksksss336.xml', 'maksssksksss33.xml', 'maksssksksss187.xml', 'maksssksksss414.xml', 'maksssksksss397.xml', 'maksssksksss60.xml', 'maksssksksss438.xml', 'maksssksksss412.xml', 'maksssksksss709.xml', 'maksssksksss120.xml', 'maksssksksss603.xml', 'maksssksksss66.xml', 'maksssksksss805.xml', 'maksssksksss515.xml', 'maksssksksss747.xml', 'maksssksksss823.xml', 'maksssksksss236.xml', 'maksssksksss596.xml', 'maksssksksss295.xml', 'maksssksksss836.xml', 'maksssksksss746.xml', 'maksssksksss844.xml', 'maksssksksss498.xml', 'maksssksksss776.xml', 'maksssksksss135.xml', 'maksssksksss723.xml', 'maksssksksss620.xml', 'maksssksksss637.xml', 'maksssksksss426.xml', 'maksssksksss514.xml', 'maksssksksss373.xml', 'maksssksksss615.xml', 'maksssksksss598.xml', 'maksssksksss720.xml', 'maksssksksss606.xml', 'maksssksksss672.xml', 'maksssksksss20.xml', 'maksssksksss80.xml', 'maksssksksss682.xml', 'maksssksksss745.xml', 'maksssksksss137.xml', 'maksssksksss334.xml', 'maksssksksss703.xml', 'maksssksksss567.xml', 'maksssksksss721.xml', 'maksssksksss541.xml', 'maksssksksss293.xml', 'maksssksksss105.xml', 'maksssksksss375.xml', 'maksssksksss4.xml', 'maksssksksss725.xml', 'maksssksksss824.xml', 'maksssksksss838.xml', 'maksssksksss839.xml', 'maksssksksss387.xml', 'maksssksksss431.xml', 'maksssksksss272.xml', 'maksssksksss110.xml', 'maksssksksss790.xml', 'maksssksksss543.xml', 'maksssksksss630.xml', 'maksssksksss250.xml', 'maksssksksss432.xml', 'maksssksksss549.xml', 'maksssksksss126.xml', 'maksssksksss780.xml', 'maksssksksss739.xml', 'maksssksksss237.xml', 'maksssksksss16.xml', 'maksssksksss199.xml', 'maksssksksss499.xml', 'maksssksksss768.xml', 'maksssksksss152.xml', 'maksssksksss497.xml', 'maksssksksss666. ...

# %% [markdown]
# Now, we will use the information that can be obtained from the XML files to create two csv files with some general information:
# *   The first csv file will contain information about the images, such as its filename, its size or whether it is segmented or not.
# *   The second csv file will contain information about the objects (bounding boxes), such as its label, its corresponding filename, its coordinates, etc.

# %%
# We create the images csv file
pathmetaDataImgs = os.path.join(pathMetaData, 'metaDataImgs.csv')

metaDataImgs = open(pathmetaDataImgs, "w+")

# We create the objects csv file
pathmetaDataObjs = os.path.join(pathMetaData, 'metaDataObjs.csv')

metaDataObjs = open(pathmetaDataObjs, "w+")

# We create the headers for both files
metaDataImgs.write('id_,'+ 'filename,' + 'width,' + 'height,' + 'depth,' + 'segmented' + '\n')

metaDataObjs.write('id_,' + 'label,' +'filename,' + 'x1,' + 'y1,' + 'x2,' + 'y2,' + 'pose,' + 'truncated,' + 'occluded,' + 'difficult' + '\n')


id_Objs = -1

# Now, we loop through the XML files
for id_Imgs, filename in enumerate(labelFilesNames):
    pathLabel = os.path.join(pathannotations, filename)


    with open(pathLabel) as fxml:

        # We convert the XML file into a python dictionary
        fdict = xmltodict.parse(fxml.read())

        # For each file we save the following parameters
        width = fdict['annotation']['size']['width']  # Image width
        height = fdict['annotation']['size']['height']  # Image height
        depth = fdict['annotation']['size']['depth']  # Image depth
        segmented = fdict['annotation']['segmented']  # Whether it is segmented or not

        # Then, we write these parameters in the file
        metaDataImgs.write(str(id_Imgs) + ',' + filename + ',' + width + ',' + height + ',' + depth + ',' + segmented + '\n')

        objects = fdict['annotation']['object']

        # Now, for each object found in the XML
        if type(objects) == list:
            for counter, object in enumerate(objects):
                id_Objs += 1

            # We save the following parameters
                objLabel = object['name']  # Object label

                x1 = object['bndbox']['xmin']  # Object xmin
                x2 = object['bndbox']['xmax']  # Object xmax
                y1 = object['bndbox']['ymin']  # Object ymin
                y2 = object['bndbox']['ymax']  # Object ymax

                pose = object['pose']  # Object pose
                truncated = object['truncated']  # Whether the object is truncated or not
                occluded = object['occluded']  # Whether the object is occluded or not
                difficult = object['difficult']  # From a scale, how difficult it is to identify the object
       
           # Then, we write these parameters in the file
                metaDataObjs.write(str(id_Objs) + ',' + objLabel + ',' + filename + ',' + x1 + ',' + y1 + ',' + x2 + ',' + y2 + ',' + pose
                                   + ',' + truncated + ',' + occluded + ',' + difficult + '\n')
        else:
            id_Objs +=1

            objLabel = objects['name']

            x1 = objects['bndbox']['xmin']
            x2 = objects['bndbox']['xmax']
            y1 = objects['bndbox']['ymin']
            y2 = objects['bndbox']['ymax']

            pose = objects['pose']
            truncated = objects['truncated']
            occluded = objects['occluded']
            difficult = objects['difficult']

            metaDataObjs.write(str(id_Objs) + ',' + objLabel + ',' + filename + ',' + x1 + ',' + y1 + ',' + x2 + ',' + y2 + ',' + pose
                                   + ',' + truncated + ',' + occluded + ',' + difficult + '\n')

metaDataImgs.close()
metaDataObjs.close()

# %% [markdown]
# <a name="1.3.2"></a>
# ### 1.3.2 Processing the MetaData

# %% [markdown]
# In this section we are using use pandas in order to preprocess the MedaData we just created.

# %%
# We read both csv files
dfImgs = pd.read_csv(pathmetaDataImgs)
dfObjs = pd.read_csv(pathmetaDataObjs)

# %%
# Get a description of the images df
dfImgs.describe()
# Out:
#               id_       width      height  depth  segmented
# count  853.000000  853.000000  853.000000  853.0      853.0
# mean   426.000000  370.589683  309.289566    3.0        0.0
# std    246.384185   56.224049   74.474840    0.0        0.0
# min      0.000000  193.000000  156.000000    3.0        0.0
# 25%    213.000000  301.000000  254.000000    3.0        0.0
# 50%    426.000000  400.000000  280.000000    3.0        0.0
# 75%    639.000000  400.000000  400.000000    3.0        0.0
# max    852.000000  600.000000  600.000000    3.0        0.0

# %%
# Since segmented column is just fill with zeros we are dropping it
dfImgs = dfImgs.drop('segmented', axis = 1)

# Also, since depth and id_ columns do not provide any addition information we will drop them too
dfImgs = dfImgs.drop('depth', axis = 1)
dfImgs = dfImgs.drop('id_', axis = 1)

dfImgs.head()
# Out:
#               filename  width  height
# 0  maksssksksss348.xml    301     400
# 1   maksssksksss19.xml    400     236
# 2  maksssksksss165.xml    450     463
# 3  maksssksksss764.xml    301     400
# 4  maksssksksss493.xml    301     400

# %%
# Get a description of the objects df
dfObjs.describe()
# Out:
#                id_           x1           y1  ...  truncated  occluded  difficult
# count  4072.000000  4072.000000  4072.000000  ...     4072.0    4072.0     4072.0
# mean   2035.500000   182.207024    85.780697  ...        0.0       0.0        0.0
# std    1175.629477   104.471254    52.571821  ...        0.0       0.0        0.0
# min       0.000000     1.000000     1.000000  ...        0.0       0.0        0.0
# 25%    1017.750000    96.000000    49.000000  ...        0.0       0.0        0.0
# 50%    2035.500000   177.000000    75.000000  ...        0.0       0.0        0.0
# 75%    3053.250000   266.000000   113.000000  ...        0.0       0.0        0.0
# max    4071.000000   569.000000   330.000000  ...        0.0       0.0        0.0
#
# [8 rows x 8 columns]

# %%
# Check if pose column contains any relevant information
# You can see the pose is unspecified for all the objects
dfObjs[dfObjs.pose != 'Unspecified']
# Out:
# Empty DataFrame
# Columns: [id_, label, filename, x1, y1, x2, y2, pose, truncated, occluded, difficult]
# Index: []

# %%
# As pose column is filled with "Unspecified" we will drop it, together with other irrelevant columns
dfObjs = dfObjs.drop(['id_', 'pose', 'truncated', 'occluded', 'difficult'], axis = 1)

dfObjs.head()
# Out:
#           label             filename   x1   y1   x2   y2
# 0  without_mask  maksssksksss348.xml   86  189  188  304
# 1  without_mask   maksssksksss19.xml    1   45   18   68
# 2     with_mask   maksssksksss19.xml   89   38  115   62
# 3  without_mask   maksssksksss19.xml  161   20  195   54
# 4     with_mask   maksssksksss19.xml  104  104  182  175

# %%
# Now, merge both tables using the filename column
dfObjsm = pd.merge(dfObjs, dfImgs, on = 'filename')

dfObjsm.head()
# Out:
#           label             filename   x1   y1   x2   y2  width  height
# 0  without_mask  maksssksksss348.xml   86  189  188  304    301     400
# 1  without_mask   maksssksksss19.xml    1   45   18   68    400     236
# 2     with_mask   maksssksksss19.xml   89   38  115   62    400     236
# 3  without_mask   maksssksksss19.xml  161   20  195   54    400     236
# 4     with_mask   maksssksksss19.xml  104  104  182  175    400     236

# %%
# We create new variables corresponding to the center of the bounding box
dfObjsm['center_x'] = (dfObjsm.x1 + dfObjsm.x2) // 2
dfObjsm['center_y'] = (dfObjsm.y1 + dfObjsm.y2) // 2

# We also create a normalized version of this variables
dfObjsm['norm_cx'] = dfObjsm.center_x / dfObjsm.width
dfObjsm['norm_cy'] = dfObjsm.center_y / dfObjsm.height


dfObjsm.head()
# Out:
#           label             filename   x1  ...  center_y  norm_cx   norm_cy
# 0  without_mask  maksssksksss348.xml   86  ...       246  0.45515  0.615000
# 1  without_mask   maksssksksss19.xml    1  ...        56  0.02250  0.237288
# 2     with_mask   maksssksksss19.xml   89  ...        50  0.25500  0.211864
# 3  without_mask   maksssksksss19.xml  161  ...        37  0.44500  0.156780
# 4     with_mask   maksssksksss19.xml  104  ...       139  0.35750  0.588983
#
# [5 rows x 12 columns]

# %% [markdown]
# That should be enough to get some interesting insights about our data.

# %% [markdown]
# <a name="1.3.3"></a>
# ### 1.3.3 Conclusions about the MetaData

# %% [markdown]
# The following information can be obtained just by analyzing the metadata.

# %% [markdown]
# ######  There are 853 images. In total, there are 4072 bounding boxes: 3232 for people with a mask, 717 for people without a mask, and 123 for people who use their mask incorrectly. The balance of the dataset is not the best, and in this case, it would be a good idea to obtain more samples from individuals without a mask or who use their mask incorrectly; however the purpose of this project is learning and we will accept this dataset as valid. Recall that YOLOv5 has data augmentation integrated, that will help alleviate these deficiencies

# %%
print('The total amount of bounding boxes is', dfObjsm.shape[0]) 

print('There are', dfObjsm[dfObjsm['label'] == 'with_mask'].shape[0], 'individuals with mask')

print('There are', dfObjsm[dfObjsm['label'] == 'without_mask'].shape[0], 'individuals without mask')

print('There are', dfObjsm[dfObjsm['label'] == 'mask_weared_incorrect'].shape[0], 'individuals wearing their mask incorrectly')
# Out:
# The total amount of bounding boxes is 4072
# There are 3232 individuals with mask
# There are 717 individuals without mask
# There are 123 individuals wearing their mask incorrectly

# %% [markdown]
# ###### Images average size is (394, 270). Objects average size is (31, 35). Bounding boxes are quite small compared to the images size. Therefore, we can assume most of the images were taken from a considerable distance.

# %%
print('The average image width is', dfObjsm.width.mean())

print('The average image height is', dfObjsm.height.mean())
# Out:
# The average image width is 393.70284872298623
# The average image height is 270.1237721021611

# %%
print('The average object width is', (dfObjsm.x2 - dfObjsm.x1).mean())

print('The average object height is', (dfObjsm.y2 - dfObjsm.y1).mean())
# Out:
# The average object width is 31.149066797642437
# The average object height is 35.0049115913556

# %% [markdown]
# ###### The objects locations are well distributed. There are no particular regions of the $[0, 1]\times [0, 1]$ without samples.

# %%
# The following plot displays the objects normalized center
plt.figure(figsize=(10,10))
sns.scatterplot(dfObjsm.norm_cx, dfObjsm.norm_cy, dfObjsm.label)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <a name="1.4"></a>
# ## 1.4 Preprocessing

# %% [markdown]
# In this section, we are preparing the data for feeding YOLOs model. To do that, for every image in the dataset we have to create a txt file (with the same name as the image) containing the class id (in our case, it is 0 for with_mask, 1 for without_mask or 2 for mask_weared_incorrect) and the bounding box coordinates for every object in the image. For the previous example, its txt file would look like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We have to put those txt files together with the images in the same directory. Thats exactly what we are doing in the following two subsections.

# %% [markdown]
# <a name="1.4.1"></a>
# ### 1.4.1 Convert labels to YOLOs format

# %% [markdown]
# In VOC PASCAL format, XML files use coordinates (xMin, xMax, yMin, yMax) for the bounding boxes (red parameters). Meanwhile, YOLO uses normalized (x, y, w, h) where x and y are the center coordinates of the bounding box and w and h are the width and height of the bounding box (green parameters).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Labels conversion dictionary
# With mask = 0 = with_mask
# Without mask = 1 = without_mask
# Mask worn incorrectly = 2 = mask_weared_incorrect
dictLabels = {'with_mask': '0', 'without_mask': '1', 'mask_weared_incorrect': '2'}

# Loop through the XML files
for filename in labelFilesNames:

    with open(os.path.join(pathannotations, filename)) as fxml:

        pathWrite = os.path.join(pathPreprocesseddataset, filename[:-3] + 'txt')

        print(pathWrite)

        # Create a txt file with the same name as the XML file
        fYOLO = open(pathWrite, "w+")

        # Read the XML as a python dictionary
        fdict = xmltodict.parse(fxml.read())

        # Save Width and Height as we will use it later
        Width = float(fdict['annotation']['size']['width'])
        Height = float(fdict['annotation']['size']['height'])

        if type(fdict['annotation']['object']) == list:
            for counter, object in enumerate(fdict['annotation']['object']):

                # Save label, xMin, xMax, yMin, yMax
                fLabel = object['name']
                xMin = float(object['bndbox']['xmin'])
                xMax = float(object['bndbox']['xmax'])
                yMin = float(object['bndbox']['ymin'])
                yMax = float(object['bndbox']['ymax'])
                
                # Now, we create the variables we are going to write in the txt file
                label = dictLabels[fLabel]
                w = str((xMax - xMin) / Width)
                h = str((yMax - yMin) / Height)
                x = str(xMin / Width + (xMax - xMin) / Width / 2)
                y = str(yMin / Height + (yMax - yMin) / Height / 2)

                fYOLO.write(label + ' ' + x + ' ' + y + ' ' + w + ' ' + h)

                if counter < len(fdict['annotation']['object']) - 1:
                    fYOLO.write('\n')

        else:
            fLabel = fdict['annotation']['object']['name']
            xMin = float(fdict['annotation']['object']['bndbox']['xmin'])
            xMax = float(fdict['annotation']['object']['bndbox']['xmax'])
            yMin = float(fdict['annotation']['object']['bndbox']['ymin'])
            yMax = float(fdict['annotation']['object']['bndbox']['ymax'])

            label = dictLabels[fLabel]
            w = str((xMax - xMin) / Width)
            h = str((yMax - yMin) / Height)
            x = str(xMin / Width + (xMax - xMin) / Width / 2)
            y = str(yMin / Height + (yMax - yMin) / Height / 2)

            fYOLO.write(label + ' ' + x + ' ' + y + ' ' + w + ' ' + h)



        fYOLO.close()

clear_output()

# %% [markdown]
# <a name="1.4.2"></a>
# ### 1.4.2 Copy the images

# %% [markdown]
# Now, we include the images into the preprocessed dataset directory. Although it is not required because YOLOv5 does it by itself, we will also reshape the images to 640x640 size. A good practice is to use a multiple of 32 ([remember why?](https://mathchine-learning.blogspot.com/2020/10/real-time-object-detection-yolov2-and.html)).

# %%
from PIL import Image
#Target sizes
WIDTH = 640
HEIGHT = 640

for filename in imageFilesNames:
    pathResizedImage = os.path.join(pathPreprocesseddataset, filename)
    print(pathResizedImage)
    img = Image.open(os.path.join(pathimages, filename))
    ResizedImage = img.resize((WIDTH, HEIGHT))
    ResizedImage.save(pathResizedImage)

clear_output()

# %% [markdown]
# <a name="1.5"></a>
# ## 1.5 Data visualization

# %% [markdown]
# Finally, the dataset is ready for YOLO, let's visualize some samples. We constructed a function to do that.

# %%
import cv2
import random

from google.colab.patches import cv2_imshow

def drawObjects(fileName, classDict, colorDict, dir = pathPreprocesseddataset):

  """Draws the bounding boxes for the image in filename. 
     It assumes image and txt are both on the same dir.

  Args:
        filename (str): image filename without format
        classDict (dict): a dictionary with the classes as keys and the indices as values
        colorDict (dict): a dict with keys 'n' for n in class ids and values 
                          the corresponding BGR tuples assigned to class n
        dir (str): image directory
  Returns:
        np.array: image with bounding boxes
  """

  imgFile = os.path.join(dir, fileName)

  txtFile = os.path.join(dir, fileName[:-3] + 'txt')

  # Read the image
  img = cv2.imread(imgFile)

  invClassDict = {v: k for k, v in classDict.items()}

  # Read the txt
  with open(txtFile, 'r') as f:

    txt = f.read().split('\n')
    
    # Loop through the bounding boxes
    for bbox in txt:
      bbox = bbox.split()
      
      # Save the class
      classID = bbox[0]
      # Save the coordinates
      x = float(bbox[1])
      y = float(bbox[2])
      w = float(bbox[3])
      h = float(bbox[4])

      # opencv uses (xMin, xMax, yMin, yMax) coordinates for its draw functions
      xMin = int((x - w / 2) * img.shape[0])
      xMax = int((x + w / 2) * img.shape[0])
      yMin = int((y - h / 2) * img.shape[1])
      yMax = int((y + h / 2) * img.shape[1])
      
      # Draw a rectangle
      imgResult = cv2.rectangle(img, (xMin, yMin), (xMax, yMax), colorDict[classID], 2)

      # Write label
      imgResult = cv2.putText(img,
                 invClassDict[classID], 
                 (xMin - 3, yMin -4), 
                 cv2.FONT_HERSHEY_SIMPLEX, 
                 0.6,
                 colorDict[classID],
                 1)

  return imgResult

# %% [markdown]
# Run the cell below several times to visualize different samples.

# %%
# Pick a  random sample
randomSample = random.randint(0, len(imageFilesNames))
fileName = imageFilesNames[randomSample]

# We define the colorDict
# with_mask = Green
# without_mask = Red
# mask_weared_incorrect = Blue
colorDict = {'0': (0, 255, 0), '1': (0, 0, 255), '2': (255, 0, 0)}

# Draw the bounding boxes
imgResult = drawObjects(fileName, dictLabels, colorDict)

# Display the result
cv2_imshow(imgResult)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F48F55D6DD8>

# %% [markdown]
# <a name="1.6"></a>
# ## 1.6 Helper functions

# %% [markdown]
# These three functions are helper functions that will allow us to show the image in Colab Notebook, as well as upload and download images to and from your Cloud VM.

# %%
# Show image
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# Upload images
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# Download images
def download(path):
  from google.colab import files
  files.download(path)

# %% [markdown]
# <a name="2"></a>
# # 2. The model

# %% [markdown]
# <a name="2.1"></a>
# ## 2.1 Cloning and importing libraries

# %% [markdown]
# First, we will clone the repository and install all the dependencies in `./content/Mask_Detector/Darknet`.

# %%
#Importing neccesary libraries
import torch
from IPython.display import Image  # Display images

#Clone YOLOv5 repository from github
# !git clone https://github.com/ultralytics/yolov5 /content/Mask_Detector/Darknet

#Install the requirements
# !pip install -qr /content/Mask_Detector/Darknet/yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd content/Mask_Detector/Darknet/yolov5

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.6.0+cu101 CPU

# %% [markdown]
# <a name="2.2"></a>
# ## 2.2 Configuration files

# %% [markdown]
# Now, we have to prepare the configuration files that YOLOv5 needs to train our mask detector.

# %% [markdown]
# #### Generating train_data.txt, test_data.txt and val_data.txt

# %% [markdown]
# First configuration files needed are the train_data.txt, test_data.txt and val_data.txt files which hold the relative paths to all our training, test and validation images. These txt files look like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# These files purpose is telling YOLOv5 where it can find the training, validation and test images.
#
# The following code creates those files for us. Recall that best practice is using 70% of the data for the training set, 20% for the validation set, and 10 % for the testing set.

# %%
# Shuffle the imageFilesNames
samplesCount = len(imageFilesNames)

random.shuffle(imageFilesNames)


# Split the images in train, validation and test dataset
trainSetNames = imageFilesNames[:int(samplesCount * 0.70)]  # 70% for train
valSetNames = imageFilesNames[int(samplesCount * 0.70):int(samplesCount * 0.90)]  # 20% for validation
testSetNames = imageFilesNames[int(samplesCount * 0.90):]  # 10% for test

# Create the pathes for train_data.txt, val_data.txt and test_data.txt
pathTrainSet = os.path.join(pathConfigurationfiles, 'train_data.txt')

pathValSet = os.path.join(pathConfigurationfiles, 'val_data.txt')

pathTestSet = os.path.join(pathConfigurationfiles, 'test_data.txt')

# Write the image pathes into the files
with open(pathTrainSet, "w+") as f:
    for sample in trainSetNames:
        f.write(os.path.join(pathPreprocesseddataset, sample) + '\n')

with open(pathTestSet, "w+") as f:
    for sample in testSetNames:
        f.write(os.path.join(pathPreprocesseddataset, sample)+ '\n')

with open(pathValSet, "w+") as f:
    for sample in valSetNames:
        f.write(os.path.join(pathPreprocesseddataset, sample) + '\n')

# %% [markdown]
# #### Config file

# %% [markdown]
# We have to select the configuration related to YOLOs architecture and YOLOs training. We will choose the medium YOLOv5 model, as it has a similar amount of parameters to YOLOv4-tiny.
#
# We do not have to edit anything from the file, YOLOv5 will do it for us.

# %%
# Copy yolov5m.yaml into our Configuration files directory
# !cp /content/Mask_Detector/Darknet/models/yolov5m.yaml /content/Mask_Detector/Configuration_files

# %% [markdown]
# #### mask_detect.yaml

# %% [markdown]
# Finally, YOLOv5 needs a file called mask_detect.yaml. This file tells YOLO where it can find every txt files and, therefore, where to find each dataset.

# %%
pathyaml = os.path.join(pathConfigurationfiles, 'mask_detect.yaml')

classesNames = "['with_mask', 'without_mask', 'mask_weared_incorrect']"

yamlstr = "# train and val datasets (image directory or *.txt file with image paths)" + "\n" + \
"train: " + pathTrainSet + "\n" + \
"val: " + pathValSet + "\n" + \
"test: " + pathTestSet + "\n" + \
"# number of classes" + "\n" + \
"nc: 3" + "\n" + \
"# class names" + "\n" + \
"names: " + classesNames

with open(pathyaml, "w+") as f:
    f.write(yamlstr)

# %% [markdown]
# And thats all, now we can start training our mask detector.

# %% [markdown]
# <a name="3"></a>
# # 3. Training

# %% [markdown]
# It is time to to train our mask detector. To do that we have to run the following command.
#
# ```
# !python train.py --img <img size> --batch <batches> --epochs  <epochs>  --data  <path to yaml> --cfg <path to cfg> --weights <select pretrained weights>
# ```
#
# (-dont_show flag stops chart from popping up since Colab Notebook can not open images on the spot, -map flag overlays mean average precision on chart to see how accuracy of your model is)

# %% [markdown]
# **TRAINING TIP 1:** This training could take several hours. However, Colab Cloud Service kicks you off its VMs if you are idle for too long (30-90 mins). To avoid this hold (CTRL + SHIFT + i)  to open up the inspector view on your browser.
#
# Paste the following code into your console window and hit Enter.
# ```
# function ClickConnect(){
# console.log("Working");
# document
#   .querySelector('#top-toolbar > colab-connect-button')
#   .shadowRoot.querySelector('#connect')
#   .click()
# }
# setInterval(ClickConnect,60000)
# ```
# It will click the screen every 10 minutes so that you do not get kicked off.

# %% [markdown]
# We select the training configuration.
# - Set image size to 640 (these can be any multiple of 32). As we did in our [YOLOv4 mask detector](https://colab.research.google.com/drive/1ToS0ExEeaRV6T9qaz12GohO7Uiz8Z3iW?usp=sharing#scrollTo=pXKl3KXDSDBW)
# - Set batches size to 32.
# - Set epochs to 3000.

# %%
# !pip install -U PyYAML

# Start training 
# %cd /content/Mask_Detector/Darknet
# !python train.py --img 640 --batch 32 --epochs 300 --data /content/Mask_Detector/Configuration_files/mask_detect.yaml --cfg /content/Mask_Detector/Configuration_files/yolov5m.yaml --weights yolov5m.pt

# Copy the best weights from YOLOv5 directory to our Weights directory
# !cp /content/Mask_Detector/Darknet/runs/exp0/weights/best.pt /content/Mask_Detector/Weights

# Copy the last weights from YOLOv5 directory to our Weights directory
# !cp /content/Mask_Detector/Darknet/runs/exp0/weights/last.pt /content/Mask_Detector/Weights

# %% [markdown]
# After training for several hours with a Tesla T4 GPU, we got our mask detector.
#
# The following graph shows our models metrics.
# *   As we can see, our model location error and detection error go below 0.02 after around 100 iterations on the validation set.
# *   Our classification error is really close to zero after 200 iterations.
# *   Our models mAP is around 80%, which can also be considered really good for a real-time object detector.

# %%
# show chart.png of how custom object detector did with training
imShow('/content/Mask_Detector/Darknet/runs/exp0/results.png')

# %% [markdown]
# Since the results are pretty good, we will download the models weights.

# %%
# Download just the weights
download('/content/Mask_Detector/Weights/best.pt')


# Download the whole Mask_Detector
# %cd /content
# !zip -r ./Mask_Detector.zip ./Mask_Detector
# download('/content/Mask_Detector.zip')

# %% [markdown]
# <a name="4"></a>
# # 4. Testing

# %% [markdown]
# In this section, we will test our model. First, we will download the pretrained weights (just in case you did not train the model, otherwise you can use your own weights). After that, we will test our model on images and videos.

# %% [markdown]
# <a name="4.1"></a>
# ## 4.1 Fast setup (optional)

# %% [markdown]
# In case you decided to skip directly to the Testing section, please run the following cell to download the pretrained mask detector model from our github respository.

# %%
# Clone our GitHub repository
# !git clone https://github.com/amirferoua/Project-Real-Time-Mask-Detector-YOLOv5 Mask_Detector
# Clone our YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5 Mask_Detector/Darknet

# %% [markdown]
# Define some helper functions

# %%
# Show image
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# Upload images
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# Download images
def download(path):
  from google.colab import files
  files.download(path)

# %% [markdown]
# <a name="4.2"></a>
# ## 4.2 Image detection

# %% [markdown]
# Now, run detection on that image using the best weights we got after training YOLOv5m.

# %%
from IPython.display import clear_output
# Get an image from a URL:
# !wget url sample
# !wget https://c8.alamy.com/comp/2CEGM2R/students-queuing-at-the-school-entrance-wearing-mask-face-to-prevent-infection-or-respiratory-illness-turin-italy-september-2020-2CEGM2R.jpg -O /content/sample.jpg

# Upload an image from local
# upload()

# %cd /content/Mask_Detector/Darknet
# !python detect.py --weights /content/Mask_Detector/Weights/best.pt \
--img 620 --conf 0.4 --source /content/sample.jpg

# %cd /content
# clear_output()

imShow('/content/Mask_Detector/Darknet/inference/output/sample.jpg')
# Out:
# --2020-11-01 22:14:50--  https://c8.alamy.com/comp/2CEGM2R/students-queuing-at-the-school-entrance-wearing-mask-face-to-prevent-infection-or-respiratory-illness-turin-italy-september-2020-2CEGM2R.jpg
# Resolving c8.alamy.com (c8.alamy.com)... 52.9.170.225, 52.52.227.8, 52.52.162.93, ...
# Connecting to c8.alamy.com (c8.alamy.com)|52.9.170.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘/content/sample.jpg’
#
# /content/sample.jpg     [ <=>                ] 166.55K  --.-KB/s    in 0.1s
#
# Last-modified header invalid -- time-stamp ignored.
# 2020-11-01 22:14:51 (1.14 MB/s) - ‘/content/sample.jpg’ saved [170551]
#
# /content/Mask_Detector/Darknet
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=620, iou_thres=0.45, save_conf=False, save_dir='inference/output', save_txt=False, source='/content/sample.jpg', update=False, view_img=False, weights=['/content/Mask_Detector/Weights/best.pt'])
# Using CPU
#
# Fusing layers...
# Model Summary: 188 layers, 2.14767e+07 parameters, 0 gradients
# WARNING: --img-size 620 must be multiple of max stride 32, updating to 640
# image 1/1 /content/sample.jpg: 480x640 9 with_masks, Done. (1.005s)
# Results saved to inference/output
# Done. (1.079s)
# /content

# %% [markdown]
# <a name="4.3"></a>
# ## 4.3 Video detection

# %% [markdown]
# A sample video can be downloaded from [this link](https://drive.google.com/file/d/1E_N0EwPM4wkTMtLewex0einuySDrgGiK/view?usp=sharing). Upload it to Colab and run the following command.

# %%
from IPython.display import clear_output

# %cd /content/Mask_Detector/Darknet
# !python detect.py --weights /content/Mask_Detector/Weights/best.pt \
--img 620 --conf 0.4 --source /content/mask_detector_video.mp4

# %cd /content
# clear_output()

# !nvidia-smi

# %% [markdown]
# While running detection on a video, YOLOv5 shows how long it takes to process each image. The processing time is around 0.014s/image with a Tesla T4 GPU (~1800€), this is equivalent to 71 FPS.

# %% [markdown]
# In order to see the results, you have to download the video in /content/Mask_Detector/Darknet/inference/output.
#
# You can also watch our results [here](https://youtu.be/7eV3OiVIfB0), if you prefer.

# %% [markdown]
# As you can see, our mask detector is not perfect, but it still does pretty decent. Keep in mind this video contains really hard scenarios, like for example people behind glass (on the bus). In our use case, we will not have this type of obstacle and the video camera will be strategically positioned to take the images from the best possible angle.
#
# Here is a [second video](https://drive.google.com/file/d/1GTyPQUpYNfEOGZo5QNMx5_gwWb2hh7Pz/view?usp=sharing), this one is more related to the use case.

# %%
from IPython.display import clear_output

# %cd /content/Mask_Detector/Darknet
# !python detect.py --weights /content/Mask_Detector/Weights/best.pt \
--img 620 --conf 0.4 --source /content/COVID_schools.mp4

# %cd /content

# clear_output()

# %% [markdown]
# You can watch the results [here](https://youtu.be/pGoan0QkuLM).

# %% [markdown]
# <a name="4.4"></a>
# ## 4.4 Conclusion

# %% [markdown]
# We have built a real-time mask detector using YOLOv5. Our database was not the best, however, we have obtained a good detector that runs at about 45 FPS on a relatively cheap GPU, has a very low loss and a mean average precision of over 80%.
#
# In the future, we will post a comparison between this mask detector and the mask detector we built using YOLOv4 on the previous post.
